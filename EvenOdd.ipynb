# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridamdhar25-hash/Data_science_lab_SE_71/blob/main/EvenOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_odd_even(number):

    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Using the existing kernel variables:
print(f"The number {num1} is {check_odd_even(num1)}.")
print(f"The number {num2} is {check_odd_even(num2)}.")
print(f"The number {num3} is {check_odd_even(num3)}.")
# Out:
# The number 7 is Odd.
# The number 10 is Even.
# The number 0 is Even.
