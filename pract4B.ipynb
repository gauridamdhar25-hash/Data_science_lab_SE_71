# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridamdhar25-hash/Data_science_lab_SE_71/blob/main/pract4B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
mean = 0
std_dev = 1
size = 50

# Generate normal distribution
data = np.random.normal(mean, std_dev, size)

# Print the generated data
print("data set values:",data)


# Plot histogram
plt.hist(data, bins=30, color='blue', edgecolor='black')

plt.title("Normal Distribution Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()
# Out:
# data set values: [-1.04367293  1.25982327 -0.96361477  0.43820104 -0.69841857 -2.60175691
#   0.22945533 -1.14735455  0.29872351 -0.2773098   1.30211383 -1.63743467
#  -0.33163337  1.53747706 -1.36571668 -1.09920322 -1.03701424  1.00086337
#   0.31641293  1.95318486 -0.14861978  1.72585348 -0.46236628  0.48979281
#  -0.68641788  0.9972587   1.03320151 -0.19820106  2.16171797 -0.17404829
#  -0.23342925 -0.83917003  2.51835211  0.03632948  0.13791461 -1.02666224
#  -0.40433037 -0.75167623 -0.87530047 -0.68535954 -0.73177353  1.05407584
#   0.25641832 -0.01096018 -1.53879443  0.32831772  1.50174962 -0.11282142
#  -0.26651498 -0.72104481]
