# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridamdhar25-hash/Data_science_lab_SE_71/blob/main/Expertsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temp = float(input("Enter body temperature: "))

if temp > 38:
    print("Diagnosis: High Fever")
elif temp >= 37:
    print("Diagnosis: Mild Fever")
else:
    print("Diagnosis: Normal Temperature")
# Out:
# Enter body temperature: 40
# Diagnosis: High Fever
