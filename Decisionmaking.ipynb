# %% [markdown]
# <a href="https://colab.research.google.com/github/gauridamdhar25-hash/Data_science_lab_SE_71/blob/main/Decisionmaking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = 75

if score >= 60:
    print("You passed!")
else:
    print("You did not pass.")

# You can change the 'score' variable to see different outputs
score = 45

if score >= 60:
    print("You passed!")
else:
    print("You did not pass.")
# Out:
# You passed!
# You did not pass.
